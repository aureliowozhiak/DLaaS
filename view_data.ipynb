# %%
# !pip install pandas
import pandas as pd
import os
# Out:
# ...
#                                               0.0/11.0 MB ? eta -:--:--
#                                               0.1/11.0 MB 2.6 MB/s eta 0:00:05
#                                               0.2/11.0 MB 2.3 MB/s eta 0:00:05
#      -                                        0.3/11.0 MB 2.5 MB/s eta 0:00:05
#      -                                        0.4/11.0 MB 2.3 MB/s eta 0:00:05
#      --                                       0.6/11.0 MB 2.4 MB/s eta 0:00:05
#      --                                       0.6/11.0 MB 2.3 MB/s eta 0:00:05
#      --                                       0.8/11.0 MB 2.5 MB/s eta 0:00:05
#      --                                       0.8/11.0 MB 2.5 MB/s eta 0:00:05
#      --                                       0.8/11.0 MB 2.5 MB/s eta 0:00:05
#      --                                       0.8/11.0 MB 1.8 MB/s eta 0:00:06
#      ---                                      1.0/11.0 MB 1.9 MB/s eta 0:00:06
# ...

# %%
output_path = "output"
dfs = []
for filename in os.listdir(output_path):
    if filename.endswith(".csv"):
        dfs.append(pd.read_csv(os.path.join(output_path, filename), sep=";"))

# %%
for df in dfs:
    display(df)
# Out:
#                                                  href  \
# 0                                                   /
# 1                                             /#links
# 2                                              /#faqs
# 3                                              /DLaaS
# 4                                         /DataGineer
# 5                                                /api
# 6   https://didatica.tech/curso-de-python-online-p...
# 7   https://www.youtube.com/playlist?list=PLzWDDw1...
# 8   https://www.youtube.com/watch?v=rdM1iCubQsg&li...
# 9   https://panda.ime.usp.br/panda/static/pythonds...
# 10      https://dataengineer.help/knowledge/data.json
#
#                                              get_text
# 0                               🎲⚙️ DataEngineer.help
# 1                                         Links úteis
# 2                                                 FAQ
# 3                                               DLaaS
# ...
